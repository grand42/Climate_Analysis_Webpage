# %%
# Import dependencies and set up
import pandas as pd

# %%
file = "Weather_City_Data.csv"

# %%
CityDF = pd.read_csv(file)

# %%
CityDF.head()
# Out:
#                 City  Latitude  Longitude  Temp (F)  Humidity (%)  \
# 0          Busselton    -33.65     115.33     60.17            70
# 1              Khani     41.96      42.96     64.40            68
# 2          Grindavik     63.84     -22.43     41.00            86
# 3        Grand Gaube    -20.01      57.66     66.99            71
# 4  Saint Paul Harbor     57.79    -152.41     32.00            89
#
#    Cloudiness (%)  Wind Speed (mph)
# 0             100             11.92
# 1              75              3.36
# 2              40              6.93
# 3               0              3.00
# 4               1             12.75

# %%
html_table = CityDF.to_html()
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temp (F)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Busselton</td>
#       <td>-33.65</td>
#       <td>115.33</td>
#       <td>60.17</td>
#       <td>70</td>
#       <td>100</td>
#       <td>11.92</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Khani</td>
#       <td>41.96</td>
#       <td>42.96</td>
#       <td>64.40</td>
#       <td>68</td>
#       <td>75</td>
#       <td>3.36</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Grindavik</td>
#       <td>63.84</td>
#       <td>-22.43</td>
#       <td>41.00</td>
#       <td>86</td>
#       <td>40</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
